# %%
import cv2
import numpy as np 
from scipy.interpolate import interp1d
from pyefd import elliptic_fourier_descriptors
from matplotlib import pyplot as plt


# %matplotlib inline

# %%
img = cv2.imread('potato_good_malformed/Fourier_Good/Afra_12_2_1_100_3.png', cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
_, thresh = cv2.threshold(blur, 1, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(gray)
plt.show()

# %%
plt.imshow(thresh)
plt.show()

# %%
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# %%
if not contours:
    print('No contours found')

# %%
coeffs = []

for cnt in contours:
    # Find the coefficients of the contours
    coeffs.append(elliptic_fourier_descriptors(np.squeeze(cnt, axis=1), order=10))

# %%
for coef in coeffs:
    print(coef)
# Out:
# [[-1.86993942e+02 -1.86504974e+02 -1.23444165e+02  7.05401728e+01]
#  [ 3.20124895e+00  1.19207921e-01 -4.16253792e+00  5.24048847e+00]
#  [ 1.04514318e+01 -1.74397703e+01 -1.43000286e+01 -1.15665596e+01]
#  [-1.02409686e+00  5.64970420e-01  1.08222787e+00  3.38801494e+00]
#  [ 3.30318766e+00  1.86166006e+00  1.46821299e+00 -4.99554482e+00]
#  [-1.38116649e+00  9.65662087e-01  3.91720379e-01 -8.36887389e-01]
#  [-5.38338012e-01  7.65167126e-01  7.29328065e-01 -2.22969663e-01]
#  [-2.68687146e-01 -1.62837924e-01 -1.06658694e+00 -3.27533953e-01]
#  [-1.65393641e-01 -3.55046291e-01 -1.16383906e-01  3.37433586e-01]
#  [ 2.59506281e-01 -3.62351098e-01 -7.26692864e-01  2.81409648e-01]]

# %%
potato_contour = max(contours, key=cv2.contourArea)

# %%
potato_contour
# Out:
# array([[[145, 184]],
#
#        [[144, 185]],
#
#        [[143, 185]],
#
#        ...,
#
#        [[148, 184]],
#
#        [[147, 184]],
#
#        [[146, 184]]], dtype=int32)

# %%
M = cv2.moments(potato_contour)

# %%
M
# Out:
# {'m00': 117640.0,
#  'm10': 37153173.83333333,
#  'm01': 38058244.166666664,
#  'm20': 14334747222.166666,
#  'm11': 12447726056.916666,
#  'm02': 12855882581.833332,
#  'm30': 6192278131634.851,
#  'm21': 4922496707986.4,
#  'm12': 4337188385797.6997,
#  'm03': 4507863705722.95,
#  'mu20': 2600997427.1149445,
#  'mu11': 428136110.3371792,
#  'mu02': 543489271.312954,
#  'mu30': 22166141653.902344,
#  'mu21': 14569638009.90857,
#  'mu12': 15165878.161010742,
#  'mu03': -2853848311.34375,
#  'nu20': 0.1879446167864685,
#  'nu11': 0.030936546246039157,
#  'nu02': 0.039271812328461816,
#  'nu30': 0.00466984606301441,
#  'nu21': 0.0030694546557740038,
#  'nu12': 3.1950673927902097e-06,
#  'nu03': -0.0006012337424011143}

# %%
if M['m00'] == 0:
    print('No contours found')

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])

# %%
potato_contour = potato_contour.squeeze()

# %%
potato_contour
# Out:
# array([[145, 184],
#        [144, 185],
#        [143, 185],
#        ...,
#        [148, 184],
#        [147, 184],
#        [146, 184]], dtype=int32)

# %%
distances = np.sqrt((potato_contour[:, 0] - cx)**2 + (potato_contour[:, 1] - cy)**2)

# %%
distances
# Out:
# array([219.59280498, 219.73848093, 220.517573  , ..., 217.27862297,
#        218.04815982, 218.81956037])

# %%
x_old = np.linspace(0, 1, len(distances))

# %%
f = interp1d(x_old, distances, kind='linear')

# %%
x_new = np.linspace(0, 1, 256)

# %%
distances_interpolated = f(x_new)

# %%
# Normalize the interpolated distances so that the maximum distance is 250
max_distance = np.max(distances_interpolated)

# %%
distances_normalized = distances_interpolated / max_distance * 250

# %%
dft_result = np.fft.fft(distances_normalized)

# %%
dft_magnitude = np.abs(dft_result)

# %%
dft_magnitude
# Out:
# array([4.28806864e+04, 4.06400381e+02, 8.92438191e+03, 5.57324570e+02,
#        6.19558360e+02, 1.54123849e+02, 2.04902343e+02, 1.79877840e+02,
#        6.17545239e+01, 7.08132876e+01, 4.78192106e+01, 5.80505240e+01,
#        5.58362392e+01, 3.47990965e+01, 5.90999990e+01, 1.78481106e+01,
#        4.19524536e+01, 2.43663209e+01, 4.54493052e+01, 2.79023089e+01,
#        3.07667636e+01, 1.26737301e+01, 1.44619404e+01, 1.39862565e+01,
#        9.59847308e+00, 2.53675907e+01, 1.05236788e+01, 4.79555387e+00,
#        1.56450474e+01, 1.63794287e+01, 6.41949015e+00, 6.93754735e+00,
#        7.72876279e+00, 1.51023842e+01, 5.37177350e+00, 6.00677817e+00,
#        9.78037578e+00, 3.67233060e+00, 1.18393025e+01, 6.02535484e+00,
#        8.27930236e+00, 1.55833475e+01, 4.87374243e+00, 3.00589887e+00,
#        3.07909829e+00, 7.80230427e+00, 1.07307741e+01, 8.57114550e+00,
#        1.92377763e+00, 4.77406466e+00, 1.11082570e+01, 3.58984538e+00,
#        5.58442290e+00, 5.23361096e+00, 5.88714376e+00, 4.78273349e+00,
#        2.06150258e+00, 6.83618885e+00, 5.98559731e+00, 3.16617917e+00,
#        5.68962627e+00, 3.09359197e+00, 3.10238189e+00, 4.58843593e+00,
#        1.15066166e+00, 3.54655457e+00, 5.64870798e+00, 3.96597984e+00,
#        2.23571338e+00, 8.15388149e+00, 3.29212283e+00, 4.54168308e+00,
#        8.56417083e+00, 1.24511915e+00, 5.05217402e+00, 1.20898871e+00,
#        3.68358720e+00, 2.17354568e+00, 2.44792602e+00, 2.20850833e+00,
#        3.45321021e+00, 1.53422039e+00, 6.16386826e-01, 7.82899064e+00,
#        2.67961047e+00, 2.34131644e+00, 4.44402629e+00, 3.77662533e+00,
#        1.02735441e+00, 1.85110557e+00, 8.36349389e-01, 1.94668804e+00,
#        3.84516831e+00, 2.68611240e+00, 5.61472409e+00, 6.96955456e-01,
#        5.59815688e+00, 2.24139711e+00, 1.05487076e+00, 1.05674537e+00,
#        4.16974635e+00, 1.47233551e+00, 2.73356393e+00, 1.16517983e+00,
#        4.68036967e+00, 2.64825529e+00, 3.98186730e+00, 5.35843582e+00,
#        5.80443173e+00, 3.86750241e+00, 5.42334607e+00, 3.54948714e+00,
#        3.84546185e+00, 2.81567408e+00, 7.80027893e+00, 4.45278662e+00,
#        4.59606036e+00, 8.21839742e+00, 5.17563027e+00, 4.14536272e+00,
#        6.94180451e+00, 5.29302776e+00, 6.97713377e+00, 2.68930489e+00,
#        4.24275986e+00, 3.63429061e+00, 1.03873866e+00, 2.68307567e+00,
#        4.38824586e+00, 2.68307567e+00, 1.03873866e+00, 3.63429061e+00,
#        4.24275986e+00, 2.68930489e+00, 6.97713377e+00, 5.29302776e+00,
#        6.94180451e+00, 4.14536272e+00, 5.17563027e+00, 8.21839742e+00,
#        4.59606036e+00, 4.45278662e+00, 7.80027893e+00, 2.81567408e+00,
#        3.84546185e+00, 3.54948714e+00, 5.42334607e+00, 3.86750241e+00,
#        5.80443173e+00, 5.35843582e+00, 3.98186730e+00, 2.64825529e+00,
#        4.68036967e+00, 1.16517983e+00, 2.73356393e+00, 1.47233551e+00,
#        4.16974635e+00, 1.05674537e+00, 1.05487076e+00, 2.24139711e+00,
#        5.59815688e+00, 6.96955456e-01, 5.61472409e+00, 2.68611240e+00,
#        3.84516831e+00, 1.94668804e+00, 8.36349389e-01, 1.85110557e+00,
#        1.02735441e+00, 3.77662533e+00, 4.44402629e+00, 2.34131644e+00,
#        2.67961047e+00, 7.82899064e+00, 6.16386826e-01, 1.53422039e+00,
#        3.45321021e+00, 2.20850833e+00, 2.44792602e+00, 2.17354568e+00,
#        3.68358720e+00, 1.20898871e+00, 5.05217402e+00, 1.24511915e+00,
#        8.56417083e+00, 4.54168308e+00, 3.29212283e+00, 8.15388149e+00,
#        2.23571338e+00, 3.96597984e+00, 5.64870798e+00, 3.54655457e+00,
#        1.15066166e+00, 4.58843593e+00, 3.10238189e+00, 3.09359197e+00,
#        5.68962627e+00, 3.16617917e+00, 5.98559731e+00, 6.83618885e+00,
#        2.06150258e+00, 4.78273349e+00, 5.88714376e+00, 5.23361096e+00,
#        5.58442290e+00, 3.58984538e+00, 1.11082570e+01, 4.77406466e+00,
#        1.92377763e+00, 8.57114550e+00, 1.07307741e+01, 7.80230427e+00,
#        3.07909829e+00, 3.00589887e+00, 4.87374243e+00, 1.55833475e+01,
#        8.27930236e+00, 6.02535484e+00, 1.18393025e+01, 3.67233060e+00,
#        9.78037578e+00, 6.00677817e+00, 5.37177350e+00, 1.51023842e+01,
#        7.72876279e+00, 6.93754735e+00, 6.41949015e+00, 1.63794287e+01,
#        1.56450474e+01, 4.79555387e+00, 1.05236788e+01, 2.53675907e+01,
#        9.59847308e+00, 1.39862565e+01, 1.44619404e+01, 1.26737301e+01,
#        3.07667636e+01, 2.79023089e+01, 4.54493052e+01, 2.43663209e+01,
#        4.19524536e+01, 1.78481106e+01, 5.90999990e+01, 3.47990965e+01,
#        5.58362392e+01, 5.80505240e+01, 4.78192106e+01, 7.08132876e+01,
#        6.17545239e+01, 1.79877840e+02, 2.04902343e+02, 1.54123849e+02,
#        6.19558360e+02, 5.57324570e+02, 8.92438191e+03, 4.06400381e+02])

# %%
dft_magnitude = np.abs(dft_result)

# %%
plt.figure(figsize=(10, 5))

# %%
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.plot(dft_magnitude[:256 // 2])  # Plot only half (symmetrical)
plt.title('Fourier Magnitude')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')

plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.plot(dft_magnitude[:256])  # Plot only half (symmetrical)
plt.title('Fourier Magnitude')
plt.xlabel('Frequency')
plt.ylabel('Magnitude')

plt.tight_layout()
plt.show()
